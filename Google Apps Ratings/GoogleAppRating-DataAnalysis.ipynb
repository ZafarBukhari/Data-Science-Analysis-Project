# %% [markdown]
# # DATA ANALYSIS OF GOOGLE APP'S RATINGS

# %% [markdown]
# ## 1- Import the Required Module

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2- Read Data from CSV File

# %%
google_data = pd.read_csv("datasets/googleplaystore.csv")

# %%
# Inpsecting the first five rows

google_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Display basic info of dataset

google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# This will display rows and columns of dataset

google_data.shape
# Out:
# (10841, 13)

# %%
# Display total number of rows / indexes

google_data.index
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
# Display total columns of the dataset

google_data.keys()
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Display summary statistics

google_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# This will display the trend of dataset
# Rating column shows some 'outlier' exist at more than '17'

google_data.boxplot()

# %%
# this also shows abnormal activity, as there is gap between '0' to near '1' in Rating column

google_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023B5099A438>]],
#       dtype=object)

# %% [markdown]
# ## 3- Data Cleaning

# %% [markdown]
# #### Count Number of Missing Values in the DataFrame i.e. google_data

# %%
# Counting missing values

google_data.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# 5      False     False   False    False  False     False  False  False
# 6      False     False   False    False  False     False  False  False
# 7      False     False   False    False  False     False  False  False
# 8      False     False   False    False  False     False  False  False
# 9      False     False   False    False  False     False  False  False
# 10     False     False   False    False  False     False  False  False
# 11     False     False   False    False  False     False  False  False
# ...

# %%
# Count the number of missing values in each column

google_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
#     - Above scenario depicts that following columns have missing values mentioned against each:
#             1. Rating               - Missing Values = 1474
#             2. Content Rating       - Missing Values = 1
#             3. Current Ver          - Missing Values = 8
#             4. Android Ver          - Missing Values = 3

# %% [markdown]
# ### 3.1- Check how many ratings are more than 5 - Which is an Outliers

# %%
# This shows that at row-index '10472' there exists an 'outlier' which has 'rating point at 19.0'

google_data[google_data.Rating > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Dropping the outlier
# 'inplace=True' will update the DataFrame after dropping the outlier-index i.e. 10472

google_data.drop([10472], inplace=True)

# %%
# Verify that outlier existed at row-index '10472' has successfuly dropped?

google_data[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# ...

# %%
# Now again check data trend at 'boxplot()'
# It will show healthy trend between 0 ~ 5 at 'Rating' column

google_data.boxplot()

# %%
# Similary, now histogram will also show healthy trend

google_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023B50D7B0F0>]],
#       dtype=object)

# %% [markdown]
# ### 3.2- Remove Columns that are 90% empty

# %%
# Will show empty data, which comprises 10% of total indexes

threshold = len(google_data) * 0.1

threshold
# Out:
# 1084.0

# %%
# This will drop as per variable threshold

google_data.dropna(thresh = threshold, axis=1, inplace=True)

# %%
display(google_data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# ### 3.3- Data Imputation & Manipulation

# %% [markdown]
# #### Fill the Null Values with Appropriate Values using aggregate functions such as mean, median or mode

# %%
# define a function 'impute_median'

def impute_median(series):
    return series.fillna(series.median())

# %%
# Calling 'impute_medain()' function to clean the 'Rating' column withing 'transform()' function

google_data.Rating = google_data['Rating'].transform(impute_median)

# %%
# Count the number of null values in each column

google_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# Display Modes of Categorical Values

print(google_data['Type'].mode())
print()
print(google_data['Current Ver'].mode())
print()
print(google_data['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
#
# 0    Varies with device
# dtype: object
#
# 0    4.1 and up
# dtype: object

# %%
# Fill the missing categorical values with mode

google_data['Type'].fillna(str(google_data['Type'].mode().values[0]), inplace=True)
google_data['Current Ver'].fillna(str(google_data['Current Ver'].mode().values[0]), inplace=True)
google_data['Android Ver'].fillna(str(google_data['Android Ver'].mode().values[0]), inplace=True)

# %%
# count and sum the number of null values in each column

google_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# Let's convert Price, Reviews and Ratings into Numerical Values

google_data['Price'] = google_data['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
google_data['Price'] = google_data['Price'].apply(lambda x: float(x))

google_data['Reviews'] = pd.to_numeric(google_data['Reviews'], errors = 'coerce')

# %%
google_data['Installs'] = google_data['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x))
google_data['Installs'] = google_data['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
google_data['Installs'] = google_data['Installs'].apply(lambda x: float(x))

# %%
# This will show top-five rows of DataFrame

display(google_data.head(10))
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size    Installs  Type  Price Content Rating  \
# 0      159   19M     10000.0  Free    0.0       Everyone
# ...

# %%
# Display summary of DataFrame

google_data.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10840.000000  1.084000e+04  1.084000e+04  10840.000000
# mean       4.206476  4.441529e+05  1.546434e+07      1.027368
# std        0.480342  2.927761e+06  8.502936e+07     15.949703
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01  1.000000e+03      0.000000
# 50%        4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# ## 4- Data Visualization

# %%
group = google_data.groupby('Category')
x = group['Rating'].agg(np.mean)
y = group['Price'].agg(np.sum)
z = group['Reviews'].agg(np.mean)
display(x)
print("* * * * * * * * * * * *")

display(y)
print("* * * * * * * * * * * *")

display(z)
print("* * * * * * * * * * * *")
# Out:
# Category
# ART_AND_DESIGN         4.355385
# AUTO_AND_VEHICLES      4.205882
# BEAUTY                 4.283019
# BOOKS_AND_REFERENCE    4.335498
# BUSINESS               4.182391
# COMICS                 4.160000
# COMMUNICATION          4.180103
# DATING                 4.025641
# EDUCATION              4.388462
# ENTERTAINMENT          4.126174
# EVENTS                 4.395313
# FAMILY                 4.204564
# FINANCE                4.151639
# FOOD_AND_DRINK         4.185827
# GAME                   4.286888
# HEALTH_AND_FITNESS     4.280059
# HOUSE_AND_HOME         4.211364
# LIBRARIES_AND_DEMO     4.207059
# LIFESTYLE              4.131414
# MAPS_AND_NAVIGATION    4.075182
# MEDICAL                4.216199
# NEWS_AND_MAGAZINES     4.161837
# PARENTING              4.300000
# PERSONALIZATION        4.328827
# PHOTOGRAPHY            4.197910
# PRODUCTIVITY           4.226651
# SHOPPING               4.263077
# SOCIAL                 4.261017
# SPORTS                 4.236458
# ...

# %%
plt.figure(figsize=(14,8))
plt.plot(x, 'ro', color='g')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.plot(x,'ro', color='r')
plt.xticks(rotation=90)
plt.title('Category Wise Rating')
plt.xlabel('Categories - - - >')
plt.ylabel('Ratings - - - >')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(y,'r--', color='b')
plt.xticks(rotation=90)
plt.title('Category Wise Rating')
plt.xlabel('Categories - - - >')
plt.ylabel('Ratings - - - >')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(z,'bs', color='g')
plt.xticks(rotation=90)
plt.title('Category wise Reviews')
plt.xlabel('Categories-->')
plt.ylabel('Reviews-->')
plt.show()
